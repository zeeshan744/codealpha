# %%
import pandas as pd

# Load the datasets
df_india = pd.read_csv('/content/Unemployment in India.csv')
df_covid = pd.read_csv('/content/Unemployment_Rate_upto_11_2020.csv')

# Display the first few rows and the column names
print("Unemployment in India Dataset:")
print(df_india.head())
print("\nColumns in Unemployment in India Dataset:")
print(df_india.columns.tolist())

print("\nUnemployment Rate Upto Nov 2020 Dataset:")
print(df_covid.head())
print("\nColumns in Unemployment Rate Upto Nov 2020 Dataset:")
print(df_covid.columns.tolist())
# Out:
# Unemployment in India Dataset:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural
#
# Columns in Unemployment in India Dataset:
# ...

# %%
# Strip spaces from column names
df_india.columns = df_india.columns.str.strip()
df_covid.columns = df_covid.columns.str.strip()

# Fill or drop missing values as appropriate
df_india.fillna(method='ffill', inplace=True)
df_covid.fillna(method='ffill', inplace=True)

# Convert date columns to datetime format
df_india['Date'] = pd.to_datetime(df_india['Date'])
df_covid['Date'] = pd.to_datetime(df_covid['Date'])
# Out:
# <ipython-input-3-ff69cea9fd7e>:6: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_india.fillna(method='ffill', inplace=True)
# <ipython-input-3-ff69cea9fd7e>:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_covid.fillna(method='ffill', inplace=True)
# <ipython-input-3-ff69cea9fd7e>:10: UserWarning: Parsing dates in  %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_india['Date'] = pd.to_datetime(df_india['Date'])
# <ipython-input-3-ff69cea9fd7e>:11: UserWarning: Parsing dates in  %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_covid['Date'] = pd.to_datetime(df_covid['Date'])

# %%
# Load the datasets
df_india = pd.read_csv('/content/Unemployment in India.csv')

# Check the columns of the dataset
print("Columns in Unemployment in India Dataset:")
print(df_india.columns.tolist())
# Out:
# Columns in Unemployment in India Dataset:
# ['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)', ' Estimated Employed', ' Estimated Labour Participation Rate (%)', 'Area']

# %%
# Strip spaces from column names
df_india.columns = df_india.columns.str.strip()

# Now check the column names again
print("Columns in Unemployment in India Dataset after stripping:")
print(df_india.columns.tolist())
# Out:
# Columns in Unemployment in India Dataset after stripping:
# ['Region', 'Date', 'Frequency', 'Estimated Unemployment Rate (%)', 'Estimated Employed', 'Estimated Labour Participation Rate (%)', 'Area']

# %%
# Set the date as the index for easier plotting
df_india.set_index('Date', inplace=True)

# Check if it was set correctly
print("Index of the DataFrame:")
print(df_india.index)
# Out:
# Index of the DataFrame:
# Index([' 31-05-2019', ' 30-06-2019', ' 31-07-2019', ' 31-08-2019',
#        ' 30-09-2019', ' 31-10-2019', ' 30-11-2019', ' 31-12-2019',
#        ' 31-01-2020', ' 29-02-2020',
#        ...
#                  nan,           nan,           nan,           nan,
#                  nan,           nan,           nan,           nan,
#                  nan,           nan],
#       dtype='object', name='Date', length=768)

# %%
import pandas as pd

# Load the dataset
df_india = pd.read_csv('/content/Unemployment in India.csv')

# Check the columns of the dataset
print("Columns in Unemployment in India Dataset:")
print(df_india.columns.tolist())

# Strip spaces from column names
df_india.columns = df_india.columns.str.strip()

# Check the column names again after stripping
print("Columns in Unemployment in India Dataset after stripping:")
print(df_india.columns.tolist())

# Convert date column to datetime format if it exists
if 'Date' in df_india.columns:
    df_india['Date'] = pd.to_datetime(df_india['Date'])
    # Set the date as the index
    df_india.set_index('Date', inplace=True)
    print("Index of the DataFrame:")
    print(df_india.index)
else:
    print("The 'Date' column does not exist.")
# Out:
# Columns in Unemployment in India Dataset:
# ['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)', ' Estimated Employed', ' Estimated Labour Participation Rate (%)', 'Area']
# Columns in Unemployment in India Dataset after stripping:
# ['Region', 'Date', 'Frequency', 'Estimated Unemployment Rate (%)', 'Estimated Employed', 'Estimated Labour Participation Rate (%)', 'Area']
# Index of the DataFrame:
# DatetimeIndex(['2019-05-31', '2019-06-30', '2019-07-31', '2019-08-31',
#                '2019-09-30', '2019-10-31', '2019-11-30', '2019-12-31',
#                '2020-01-31', '2020-02-29',
#                ...
#                       'NaT',        'NaT',        'NaT',        'NaT',
#                       'NaT',        'NaT',        'NaT',        'NaT',
#                       'NaT',        'NaT'],
#               dtype='datetime64[ns]', name='Date', length=768, freq=None)
# ...

# %%
# Load the dataset again (if necessary)
df_india = pd.read_csv('/content/Unemployment in India.csv')

# Strip spaces from column names
df_india.columns = df_india.columns.str.strip()

# Display the columns
print("Columns in Unemployment in India Dataset:")
print(df_india.columns.tolist())
# Out:
# Columns in Unemployment in India Dataset:
# ['Region', 'Date', 'Frequency', 'Estimated Unemployment Rate (%)', 'Estimated Employed', 'Estimated Labour Participation Rate (%)', 'Area']

# %%
# Load the dataset again (if necessary)
df_india = pd.read_csv('/content/Unemployment in India.csv')

# Strip spaces from column names
df_india.columns = df_india.columns.str.strip()

# Display the columns to check for correct names
print(df_india.columns.tolist())

# Replace 'Estimated Unemployment Rate' with the actual column name from the printed list
plt.plot(df_india['Estimated Unemployment Rate (%)'], label='Estimated Unemployment Rate in India', color='blue')
# Added (%) to match the actual column name from the CSV
# Out:
# ['Region', 'Date', 'Frequency', 'Estimated Unemployment Rate (%)', 'Estimated Employed', 'Estimated Labour Participation Rate (%)', 'Area']

# %%
# After cleaning the column names
# Replace with the actual name you found
unemployment_rate_column = 'Estimated Unemployment Rate (%)'  # Update this based on your findings

# Plotting unemployment trends in India
plt.figure(figsize=(12, 6))
plt.plot(df_india[unemployment_rate_column], label='Estimated Unemployment Rate in India', color='blue')
plt.title('Estimated Unemployment Rate (%) in India Over Time')
plt.xlabel('Date')
plt.ylabel('Estimated Unemployment Rate (%)')
plt.axvline(pd.Timestamp('2020-03-01'), color='red', linestyle='--', label='COVID-19 Start')
plt.legend()
plt.grid()
plt.show()
